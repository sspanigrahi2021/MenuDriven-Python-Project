# %%
import webbrowser
import requests
import os


# Define functions for each menu option
def open_notepad():
    os.startfile("notepad.exe")

def open_chrome():
    webbrowser.open("https://www.google.com/")

def open_whatsapp():
    webbrowser.open("https://web.whatsapp.com/")

def send_email():
    recipient = input("Enter recipient email address: ")
    subject = input("Enter email subject: ")
    message = input("Enter email message: ")


def send_sms():
    recipient_phone_number = input("Enter recipient phone number: ")
    message = input("Enter SMS message: ")

def open_chatgpt():
    webbrowser.open("https://chat.openai.com/")

def show_geolocation():
    webbrowser.open("https://www.google.com/maps/search/?api=1&query=my+location")

def get_trending_topics_twitter():
    response = requests.get("https://api.twitter.com/1.1/trends/place.json?id=1")
    data = response.json()

    trending_topics = []
    for trend in data["trends"]:
        trending_topics.append(trend["name"])

    print("Trending topics on Twitter:")
    for topic in trending_topics:
        print(topic)

def get_top_posts_hashtag_twitter():
    hashtag = input("Enter hashtag: ")

    response = requests.get(
        f"https://api.twitter.com/1.1/search/tweets.json?q={hashtag}&count=10"
    )
    data = response.json()

    top_posts = []
    for tweet in data["statuses"]:
        top_posts.append(tweet["text"])

    print(f"Top 10 posts for hashtag #{hashtag}:")
    for post in top_posts:
        print(post)

def scrape_medium_or_wikipedia_page():
    url = input("Enter URL of Medium or Wikipedia page: ")


def play_audio():
    audio_file = input("Enter audio file path: ")

    player = vlc.MediaPlayer(audio_file)
    player.play()

    while True:
        choice = input("Enter 'q' to quit: ")
        if choice == "q":
            break

def play_video():
    video_file = input("Enter video file path: ")

    player = vlc.MediaPlayer(video_file)
    player.play()

    while True:
        choice = input("Enter 'q' to quit: ")
        if choice == "q":
            break

def control_speaker_sound_while_speaking_text():
    text = input("Enter text to speak: ")

def post_on_linkedin():
    post_content = input("Enter LinkedIn post content: ")
while True:
    print("Main Menu:")
    print("1. Open Notepad")
    print("2. Open Chrome")
    print("3. Open WhatsApp")
    print("4. Send Email")
    print("5. Send SMS")
    print("6. Open ChatGPT")
    print("7. Show Geolocation")
    print("8. Get Trending Topics on Twitter")
    print("9. Get Top Posts for Hashtag on Twitter")
    print("10. Scrape Medium or Wikipedia Page")
    print("11. Play Audio")
    print("12. Play Video")
    print("13. Control Speaker Sound While Speaking Text")
    choice = input("Enter your choice: ")
    if choice == "1":
        open_notepad()
    elif choice == "2":
        open_chrome()
    elif choice == "3":
        open_whatsapp()
    elif choice == "4":
        send_email()
    elif choice == "5":
        send_sms()
    elif choice == "6":
        open_chatgpt()
    elif choice == '7':
        get_geolocation()
    elif choice == '8':
        get_twitter_trending_topic()
    elif choice == '9':
        get_twitter_hashtag_posts()
    elif choice == '10':
        get_data_from_page()
    elif choice == '11':
        play_audio()
    elif choice == '12':
        play_video()
    elif choice == '13':
        speak_text()
    else:
        print("Invalid choice. Please enter a number between 0 and 13.")
# Out:
# Main Menu:
# 1. Open Notepad
# 2. Open Chrome
# 3. Open WhatsApp
# 4. Send Email
# 5. Send SMS
# 6. Open ChatGPT
# 7. Show Geolocation
# 8. Get Trending Topics on Twitter
# 9. Get Top Posts for Hashtag on Twitter
# 10. Scrape Medium or Wikipedia Page
# 11. Play Audio
# 12. Play Video
# 13. Control Speaker Sound While Speaking Text
